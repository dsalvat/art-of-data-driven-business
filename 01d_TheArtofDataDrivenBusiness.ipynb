# %% [markdown]
# <a href="https://colab.research.google.com/github/dsalvat/art-of-data-driven-business/blob/main/01d_TheArtofDataDrivenBusiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

penguins = sns.load_dataset("penguins")
f, ax = plt.subplots(figsize=(12, 6))
sns.histplot(data=penguins, x="flipper_length_mm", bins=30)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize=(12,6))
sns.histplot(data=penguins, x="flipper_length_mm", kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize=(12, 6))
sns.histplot(data=penguins, x="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.pairplot(penguins, height=3)

# %%
sns.pairplot(penguins, hue="species", diag_kind="hist", height=3)

# %%
sns.pairplot(
    penguins,
    x_vars=["bill_length_mm", "bill_depth_mm",
            "flipper_length_mm"],
    y_vars=["bill_length_mm", "bill_depth_mm"],
    height=3
)

# %%
tips = sns.load_dataset("tips")
f, ax = plt.subplots(figsize=(12,6))
ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
f, ax = plt.subplots(figsize=(12,6))
ax = sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="Set3")
